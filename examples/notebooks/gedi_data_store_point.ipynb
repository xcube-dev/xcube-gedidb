# %% [markdown]
# # xcube GEDI Data Store using `point`
#
# This notebook provides a walk-through demonstrating how to use the xcube-gedi plugin to read and explore data from the GEDI API using the `gedidb` pacakge.
#
# The `gedidb` package allows to query the data as xarray datasets in two modes: `bounding_box` where need to provide a bbox and `nearest` where we need to provide a point.
#
# This notebook shows how to access this store using `point`

# %%
# %%time
from xcube.core.store import new_data_store
import logging
# Out:
# CPU times: user 2.33 s, sys: 265 ms, total: 2.6 s
# Wall time: 1.37 s

# %%
store = new_data_store("gedi")

# %% [markdown]
# We can set the logging level here for this plugin as follows:

# %%
logging.getLogger("xcube.gedi").setLevel(logging.INFO)

# %% [markdown]
# In this data store, we are defining the data_ids as the processed level datasets that are available via [gedidb](/https://gedidb.readthedocs.io/).
#
# These data_ids have no attributes and it will return an empty dict when requested with `include_attrs`

# %%
store.list_data_ids()
# Out:
# ['L4A', 'L2B', 'L2A', 'L4C', 'all']

# %%
store.list_data_ids(include_attrs=True)
# Out:
# 2025-06-05 14:45:41,124 - WARNING - There are no attributes for data_ids in this data store
# [('L4A', {}), ('L2B', {}), ('L2A', {}), ('L4C', {}), ('all', {})]

# %% [markdown]
# This data store has no credentials required to access data hence the data store initialization is the leanest and you just need to provide the name of the data store which is `gedi` to the `new_data_store()` method.

# %%
store.get_data_store_params_schema()
# Out:
# 2025-06-05 14:45:41,129 - INFO - This data store can be initialized without any params

# %% [markdown]
# You can also look at the data description for each level. We get this information from the [NASA CMR API](https://cmr.earthdata.nasa.gov/search/site/docs/search/api.html)
#
# Although, it is not retrievable via API, after reading the documentation for these datasets supported by `gedidb`, the `CRS` for all these data_ids is `EPSG:4326`.
#
# Links to documentation sources:
#
# - [https://docs.terrabyte.lrz.de/datasets/gedi/introduction/](https://docs.terrabyte.lrz.de/datasets/gedi/introduction/)
# - [https://lpdaac.usgs.gov/products/gedi02_av002/](https://lpdaac.usgs.gov/products/gedi02_av002/)
# - [https://lpdaac.usgs.gov/documents/986/GEDI02_UserGuide_V2.pdf](https://lpdaac.usgs.gov/documents/986/GEDI02_UserGuide_V2.pdf)
# - [https://lpdaac.usgs.gov/products/gedi02_bv002/](https://lpdaac.usgs.gov/products/gedi02_bv002/)

# %%
store.describe_data("L4A")

# %% [markdown]
# The error below is expected and it explains why. This is just FYI

# %%
store.describe_data("all")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 store.describe_data("all")
#
# File ~/miniforge3/envs/xcube-gedi/lib/python3.13/site-packages/xcube_gedi/store.py:118, in GediDataStore.describe_data(self, data_id, data_type)
#     116     raise ValueError("No such data_id found.")
#     117 if data_id == "all":
# --> 118     raise ValueError(
#     119         "`all` is just a placeholder to allow users to "
#     120         "choose variables from various levels into a "
#     121         "single data cube. Please provide a valid data_id (level_name) "
#     122         "instead"
#     123     )
#     125 metadata = dict(**self._get_gedi_metadata(_GEDI_CONCEPT_IDS.get(data_id)))
#     126 return DataDescriptor(data_id, data_type, **metadata)
#
# ValueError: `all` is just a placeholder to allow users to choose variables from various levels into a single data cube. Please provide a valid data_id (level_name) instead

# %% [markdown]
# To open a dataset from this store, you would need to provide the `data_id`, and the `variables` that you need from that `data_id`. If you want to mix different variables from various levels use `all` as data_id as shown in the example a few cells below.
#
# To find the variables, you can either provide the data_id or not at all. The variables will be then filtered based on your input.
#
# In the output `JSONSchema` below, you can expand into `properties.variables.enum` to get all the variables and its description separated by `:`.
#
# The variable name that you should use is the one that comes before `:`, for e.g. `"agbd: Aboveground biomass density"`, here the variable name is `agbd`.

# %%
store.get_open_data_params_schema()

# %% [markdown]
# There is also a class variable which returns all the available variables as the pandas

# %%
store.all_supported_variables
# Out:
#                                                         description    dtype  \
# agbd                                    Aboveground biomass density  float32
# agbd_pi_lower     Lower prediction interval for aboveground biom...  float32
# agbd_pi_upper     Upper prediction interval for aboveground biom...  float32
# agbd_se               Standard error of aboveground biomass density  float32
# agbd_t                                Model prediction in fit units  float32
# ...                                                             ...      ...
# wsci_xy_pi_upper  Horizontal Structural Complexity upper predict...  float32
# wsci_z                               Vertical Structural Complexity  float32
# wsci_z_pi_lower   Vertical Structural Complexity lower predictio...  float32
# wsci_z_pi_upper   Vertical Structural Complexity upper predictio...  float32
# zcross            Sample number of center of lowest mode above n...  float32
#
#                  product_level         units  profile_length
# agbd                       L4A         Mg/ha             NaN
# agbd_pi_lower              L4A         Mg/ha             NaN
# agbd_pi_upper              L4A         Mg/ha             NaN
# agbd_se                    L4A         Mg/ha             NaN
# agbd_t                     L4A  adimensional             NaN
# ...                        ...           ...             ...
# wsci_xy_pi_upper           L4C  adimensional             NaN
# wsci_z                     L4C  adimensional             NaN
# wsci_z_pi_lower            L4C  adimensional             NaN
# wsci_z_pi_upper            L4C  adimensional             NaN
# zcross                     L2A   Nanoseconds             NaN
#
# [84 rows x 5 columns]

# %% [markdown]
# As there are no opener IDS, you will get the following expected error when calling this method

# %%
store.get_data_opener_ids()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 store.get_data_opener_ids()
#
# File ~/miniforge3/envs/xcube-gedi/lib/python3.13/site-packages/xcube_gedi/store.py:131, in GediDataStore.get_data_opener_ids(self, data_id, data_type)
#     128 def get_data_opener_ids(
#     129     self, data_id: str = None, data_type: DataTypeLike = None
#     130 ) -> Tuple[str, ...]:
# --> 131     raise NotImplementedError(
#     132         "Since we use gedidb to request the data, which has already been "
#     133         "converted from HDF5 to TileDB arrays, there are no data opener "
#     134         "IDs available. The open_data() method always returns an xarray object."
#     135     )
#
# NotImplementedError: Since we use gedidb to request the data, which has already been converted from HDF5 to TileDB arrays, there are no data opener IDs available. The open_data() method always returns an xarray object.

# %% [markdown]
# You can check the type of data that is returned from the `open_data()` method.

# %%
store.get_data_types()
# Out:
# ('dataset',)

# %%
store.get_data_types_for_data('L4C')
# Out:
# ('dataset',)

# %% [markdown]
# NOTE: Please keep in mind, that there are several assertions in the open_data to make sure that the expected parameters are passed. One example can be seen below:

# %%
# %%time
point=(8.948581, 50.716982)
num_shots=10
radius=0.1
query_type="nearest"
start_time = "2023-01-01"
end_time = "2024-07-02"

gedi_data = store.open_data(
    data_id="L4C",
    point=point,
    query_type=query_type,
    start_time=start_time,
    end_time=end_time,
    num_shots=10,
    radius=0.1
)

gedi_data
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File <timed exec>:8
#
# File ~/miniforge3/envs/xcube-gedi/lib/python3.13/site-packages/xcube_gedi/store.py:204, in GediDataStore.open_data(self, data_id, opener_id, **open_params)
#     196 def open_data(
#     197     self,
#     198     data_id: str,
#     199     opener_id: str = None,
#     200     **open_params,
#     201 ) -> xr.Dataset:
#     202     assert data_id in self.data_ids
# --> 204     assert open_params.get("variables", None) is not None, "Variables are missing."
#     206     vars_selected = open_params.get("variables")
#     207     if data_id == "all":
#
# AssertionError: Variables are missing.

# %% [markdown]
# Now, let us use the `open_data` method to open a dataset for `L4C` and the variable `wsci` and other parameters as you can see below.

# %%
# %%time

point=(8.948581, 50.716982)
num_shots=10
radius=0.1
query_type="nearest"
vars_selected = ["wsci"]
start_time = "2023-01-01"
end_time = "2024-07-02"

gedi_data = store.open_data(
    data_id="L4C",
    variables=vars_selected,
    point=point,
    query_type=query_type,
    start_time=start_time,
    end_time=end_time,
    num_shots=10,
    radius=0.1
)
# Out:
# CPU times: user 1.88 s, sys: 6.29 s, total: 8.17 s
# Wall time: 12.2 s

# %%
gedi_data
# Out:
# <xarray.Dataset> Size: 360B
# Dimensions:      (shot_number: 10)
# Coordinates:
#   * shot_number  (shot_number) uint64 80B 234911100300153462 ... 234911100300...
#     latitude     (shot_number) float64 80B 50.72 50.72 50.72 ... 50.72 50.72
#     longitude    (shot_number) float64 80B 8.948 8.947 8.947 ... 8.951 8.952
#     time         (shot_number) datetime64[ns] 80B 2023-02-04 ... 2023-02-04
# Data variables:
#     wsci         (shot_number) float32 40B 9.252 8.179 8.1 ... 10.35 9.759 10.33

# %%
gedi_data.wsci.plot(x='latitude')

# %%
lat = gedi_data['latitude'].values
lon = gedi_data['longitude'].values
agbd = gedi_data['wsci'].values


import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sc = plt.scatter(lon, lat, c=agbd, cmap='viridis', s=10)
plt.colorbar(sc, label='wsci')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Spatial Plot of wsci')
plt.grid(True)
plt.show()

# %% [markdown]
# Now let us also include a variable from `L2A`, to do that, use `data_id="all"`

# %%
# %%time

point=(8.948581, 50.716982)
num_shots=10
radius=0.1
query_type="nearest"
vars_selected = ["wsci", "agbd"]
start_time = "2023-01-01"
end_time = "2024-07-02"

gedi_data = store.open_data(
    data_id="all",
    variables=vars_selected,
    point=point,
    query_type=query_type,
    start_time=start_time,
    end_time=end_time,
    num_shots=10,
    radius=0.1
)
# Out:
# CPU times: user 1.34 s, sys: 3.79 s, total: 5.13 s
# Wall time: 8.04 s

# %%
gedi_data
# Out:
# <xarray.Dataset> Size: 400B
# Dimensions:      (shot_number: 10)
# Coordinates:
#   * shot_number  (shot_number) uint64 80B 234911100300153462 ... 234911100300...
#     latitude     (shot_number) float64 80B 50.72 50.72 50.72 ... 50.72 50.72
#     longitude    (shot_number) float64 80B 8.948 8.947 8.947 ... 8.951 8.952
#     time         (shot_number) datetime64[ns] 80B 2023-02-04 ... 2023-02-04
# Data variables:
#     agbd         (shot_number) float32 40B 53.25 28.39 27.66 ... 144.3 176.3
#     wsci         (shot_number) float32 40B 9.252 8.179 8.1 ... 10.35 9.759 10.33

# %%
lat = gedi_data['latitude'].values
lon = gedi_data['longitude'].values
agbd = gedi_data['agbd'].values


import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sc = plt.scatter(lon, lat, c=agbd, cmap='viridis', s=10)
plt.colorbar(sc, label='agbd')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Spatial Plot of agbd')
plt.grid(True)
plt.show()
